# %% [markdown]
# <a href="https://colab.research.google.com/github/milanshetake/basic.txt/blob/main/KnestObjectDEtectionFinalResult.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-148-gfb1e746 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 1 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-148-gfb1e746 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-148-gfb1e746 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/IMG_0067.JPG: 640x448 (no detections), 42.3ms
# image 2/2 /content/yolov5/data/images/IMG_9920.JPG: 640x448 (no detections), 9.0ms
# Speed: 0.6ms pre-process, 25.6ms inference, 4.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights runs/train/exp12/weights/last.pt --img 640 --conf 0.5 --source data/images
# Out:
# detect: weights=['runs/train/exp12/weights/last.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-148-gfb1e746 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7053277 parameters, 0 gradients, 15.9 GFLOPs
# image 1/2 /content/yolov5/data/images/IMG_0067.JPG: 640x448 (no detections), 63.3ms
# image 2/2 /content/yolov5/data/images/IMG_9920.JPG: 640x448 (no detections), 8.5ms
# Speed: 0.7ms pre-process, 35.9ms inference, 19.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !zip -r /content/content.zip /content
from google.colab import files
files.download("/content/content.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2023.04.19/ (stored 0%)
#   adding: content/.config/logs/2023.04.19/13.36.21.227706.log (deflated 58%)
#   adding: content/.config/logs/2023.04.19/13.35.48.928802.log (deflated 58%)
#   adding: content/.config/logs/2023.04.19/13.36.46.154237.log (deflated 57%)
#   adding: content/.config/logs/2023.04.19/13.36.12.831704.log (deflated 86%)
#   adding: content/.config/logs/2023.04.19/13.36.46.970201.log (deflated 56%)
# ...
